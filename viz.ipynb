# %% [markdown]
# ### Placeholder

# %%
from viz import get_unique_stemmed_viz, get_unique_lemmed_viz, repo_language, idf_words_viz

# %%
get_unique_stemmed_viz()

# %%
get_unique_lemmed_viz()

# %%
idf_words_viz()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2f2870774bd8> in <module>
# ----> 1 idf_words_viz()
#
# ~/codeup-data-science/nlp_project/viz.py in idf_words_viz()
#      44     Shows bar plot for 2 given points
#      45     '''
# ---> 46     sns.barplot(data=words_idf, x='idf', y='words', palette="Blues_d")
#      47     plt.title('IDF of most common words')
#      48     plt.show()
#
# NameError: name 'words_idf' is not defined

# %%
repo_language()
